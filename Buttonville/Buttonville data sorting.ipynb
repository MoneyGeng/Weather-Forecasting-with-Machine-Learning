# %%
import pandas as pd

# %%
path = 'en_climate_monthly_ON_615HMAK_1986-2015_P1M.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Longitude (x)  Latitude (y)           Station Name Climate ID Date/Time  \
# 0         -79.37         43.86  TORONTO BUTTONVILLE A    615HMAK   1986-01
# 1         -79.37         43.86  TORONTO BUTTONVILLE A    615HMAK   1986-02
# 2         -79.37         43.86  TORONTO BUTTONVILLE A    615HMAK   1986-03
# 3         -79.37         43.86  TORONTO BUTTONVILLE A    615HMAK   1986-04
# 4         -79.37         43.86  TORONTO BUTTONVILLE A    615HMAK   1986-05
#
#    Year  Month  Mean Max Temp (°C) Mean Max Temp Flag  Mean Min Temp (°C)  \
# 0  1986      1                 NaN                  M                 NaN
# 1  1986      2                 NaN                  M                 NaN
# 2  1986      3                 NaN                  M                 NaN
# 3  1986      4                 NaN                  M                 NaN
# 4  1986      5                 NaN                  M                 NaN
#
# ...

# %%
df['Month'] = df['Month'].apply(lambda x: pd.to_datetime(str(x), format='%m').strftime('%b'))

# %%
df_temp = df.pivot(index='Year', columns='Month', values='Mean Temp (°C)')

# %%
months_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df_temp = df_temp[months_order]

# %%
df_temp = df_temp.reset_index().rename_axis(None, axis=1)

# %%
df_temp.head()
# Out:
#    Year  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep  Oct  Nov   Dec
# 0  1986  NaN  NaN  NaN  NaN   NaN  16.5  20.6  17.9  14.2  8.0  0.9  -1.8
# 1  1987 -5.6 -7.0  1.4  8.6  14.2  18.7  22.0  18.9  14.8  6.2  2.1  -1.2
# 2  1988 -5.8 -7.9 -1.7  5.6  13.7  17.4  22.4  20.5  14.3  6.2  3.9  -3.9
# 3  1989 -3.5 -7.4 -2.8  4.0  12.6  18.2  21.4  18.9  14.7  9.0  1.1 -11.0
# 4  1990 -1.9 -4.3  0.3  8.0  11.5  18.5  20.8  20.2  14.9  8.9  3.9  -1.8

# %%
# Drop duplicated rows
df_clean_temp = df_temp.drop_duplicates()

# Drop rows with missing values
df_clean_temp = df_temp.dropna()

df_clean_temp
# Out:
#     Year   Jan  Feb  Mar   Apr   May   Jun   Jul   Aug   Sep   Oct  Nov   Dec
# 1   1987  -5.6 -7.0  1.4   8.6  14.2  18.7  22.0  18.9  14.8   6.2  2.1  -1.2
# 2   1988  -5.8 -7.9 -1.7   5.6  13.7  17.4  22.4  20.5  14.3   6.2  3.9  -3.9
# 3   1989  -3.5 -7.4 -2.8   4.0  12.6  18.2  21.4  18.9  14.7   9.0  1.1 -11.0
# 4   1990  -1.9 -4.3  0.3   8.0  11.5  18.5  20.8  20.2  14.9   8.9  3.9  -1.8
# 5   1991  -6.7 -3.2  1.0   8.3  16.1  20.1  21.7  21.3  14.6   9.8  2.0  -3.2
# 6   1992  -5.1 -5.1 -1.7   5.1  12.2  16.4  17.7  17.7  14.6   6.9  2.4  -2.5
# 7   1993  -4.3 -9.5 -2.5   6.3  12.3  17.3  21.4  21.1  13.6   7.3  2.3  -3.5
# 8   1994 -13.5 -9.3 -1.1   6.8  11.5  19.1  21.2  18.6  15.8   9.3  4.8  -1.1
# 9   1995  -4.0 -8.4  1.4   3.7  13.0  19.8  21.3  21.5  13.6  10.1  0.4  -6.0
# 10  1996  -7.4 -6.7 -3.4   3.5  11.4  18.6  19.6  20.4  16.3   8.6  0.5  -0.7
# 11  1997  -6.8 -4.3 -2.1   5.7   8.9  19.5  20.1  18.2  15.3   8.5  1.6  -1.9
# ...

# %%
df_temp.to_csv("Mean Temperature (1986-2015).csv")

# %%
df_prec = df.pivot(index='Year', columns='Month', values='Total Precip (mm)')

# %%
df_prec = df_prec[months_order]

# %%
df_prec = df_prec.reset_index().rename_axis(None, axis=1)

# %%
df_prec.head()
# Out:
#    Year   Jan   Feb   Mar   Apr    May    Jun   Jul    Aug    Sep    Oct  \
# 0  1986   NaN   NaN   NaN   NaN    NaN  130.4  77.9  230.4  213.8   54.9
# 1  1987  53.1  20.9  67.3  42.6   57.4   81.0  90.2   82.8   82.6   51.0
# 2  1988  33.3  63.6  24.5  63.3   62.5   32.9  52.6   40.1   93.5   91.9
# 3  1989  24.4  31.6  42.0  38.6  100.5   82.6  36.9   97.3   89.2   96.7
# 4  1990  45.0  91.2  45.4  64.7   71.1  105.3  59.6   86.4   53.1  118.9
#
#      Nov    Dec
# 0   40.3   83.7
# 1  118.9   75.4
# 2   67.0   51.2
# 3  102.2   33.6
# 4   62.6  117.6

# %%
# Drop duplicated rows
df_clean_precip = df_prec.drop_duplicates()

# Drop rows with missing values
df_clean_precip = df_prec.dropna()

df_clean_precip
# Out:
#     Year    Jan   Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 1   1987   53.1  20.9   67.3   42.6   57.4   81.0   90.2   82.8   82.6   51.0
# 2   1988   33.3  63.6   24.5   63.3   62.5   32.9   52.6   40.1   93.5   91.9
# 3   1989   24.4  31.6   42.0   38.6  100.5   82.6   36.9   97.3   89.2   96.7
# 4   1990   45.0  91.2   45.4   64.7   71.1  105.3   59.6   86.4   53.1  118.9
# 5   1991   45.0  26.4  115.9  118.4   74.7   22.8   76.5   56.0   45.9   57.8
# 6   1992   37.4  59.2   35.3  116.0   65.7   58.2  150.4  157.2  112.7   68.8
# 7   1993   82.9  39.8   23.1   97.7   50.0  158.4   69.3   44.3   52.5   77.3
# 8   1994   67.2  24.8   55.4   81.7   75.4   59.7  103.8   46.7   58.0   24.1
# 9   1995  122.8  20.6   57.3   79.8   83.8   43.6   91.6   68.8   38.3  145.4
# 10  1996   74.6  44.6   46.1   93.8  121.7   99.6  119.5   62.8  167.6   75.3
# 11  1997   71.5  84.2   79.4   32.4   75.0   78.7   71.8   74.4   66.8   37.0
# ...

# %%
df_temp.to_csv("Total Precipitation (1986-2015).csv")
